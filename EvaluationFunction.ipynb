# %% [markdown]
# ## **Simple Chess Evaluation Function**
# Dylan Herrera \
# Uses NN architecture from this [paper](https://www.ai.rug.nl/~mwiering/GROUP/ARTICLES/ICPRAM_CHESS_DNN_2018.pdf)

# %%
import tensorflow as tf
from tensorflow import keras as ks
import pandas as pd
import numpy as np
from google.colab import drive
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def load_data(data_path, numbs):
  with open(data_path + '/scores' + str(numbs[0]) +'.npy', 'rb') as f:
    print("Accessing " + data_path + '/scores' + str(numbs[0]) +'.npy')
    Y = np.load(f)
    f.close()
  
  for i in range(numbs[0]+1, numbs[1]+1):
    with open(data_path + '/scores' + str(i) +'.npy', 'rb') as f:
      print("Accessing " + data_path + '/scores' + str(i) +'.npy')
      Y = np.append(Y, np.load(f))
      f.close()

  with open(data_path + '/positions' + str(numbs[0]) +'.npy', 'rb') as f:
    print("Accessing " + data_path + '/positions' + str(numbs[0]) +'.npy')
    X = np.load(f)
    f.close()

  for i in range(numbs[0]+1, numbs[1]+1):
    with open(data_path + '/positions' + str(i) +'.npy', 'rb') as f:
      print("Accessing " + data_path + '/positions' + str(i) +'.npy')
      X = np.concatenate((X, np.load(f)))
      f.close()

  return X, Y

# %%
def define_model():

  model = ks.Sequential([
      ks.layers.Flatten(input_shape=(64, 6)),
      ks.layers.Dense(1048, activation=tf.nn.relu),
      ks.layers.Dropout(.2),
      ks.layers.Dense(500, activation=tf.nn.relu),
      ks.layers.Dropout(.2),
      ks.layers.Dense(50, activation=tf.nn.relu),
      ks.layers.Dropout(.2),
      ks.layers.Dense(3, activation=tf.nn.softmax)
  ])

  model.compile(optimizer='adam', 
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  
  return model

# %%
def train_model_on_minibatch(data_path, numbs, model):
  X, Y = load_data(data_path, range_of_data)
  X, X_test, Y, Y_test = train_test_split(np.array(X), np.array(Y)+1)
  
  print("Training model on minibatch")
  model.fit(X, Y, epochs = 30, batch_size = 128, validation_split = .2)
  print("Evaluating performance for current model")
  predictions = model.evaluate(X_test, Y_test)

# %%
def save_model(model, model_path):
  model.save(model_path, save_format=tf)

# %%
data_path = '/content/drive/My Drive/Colab Notebooks/Chess/data'

# Train on first batch
range_of_data = [1, 2]

model = define_model()
train_model_on_minibatch(data_path, range_of_data, model)
# Out:
# Accessing /content/drive/My Drive/Colab Notebooks/Chess/data/scores1.npy
# Accessing /content/drive/My Drive/Colab Notebooks/Chess/data/scores2.npy
# Accessing /content/drive/My Drive/Colab Notebooks/Chess/data/positions1.npy
# Accessing /content/drive/My Drive/Colab Notebooks/Chess/data/positions2.npy
# Training model on minibatch
# Epoch 1/30
# 3839/3839 [==============================] - 96s 25ms/step - loss: 0.7635 - accuracy: 0.6675 - val_loss: 0.6532 - val_accuracy: 0.7254
# Epoch 2/30
# 3839/3839 [==============================] - 100s 26ms/step - loss: 0.6101 - accuracy: 0.7459 - val_loss: 0.5709 - val_accuracy: 0.7647
# Epoch 3/30
# 3839/3839 [==============================] - 95s 25ms/step - loss: 0.5326 - accuracy: 0.7809 - val_loss: 0.5323 - val_accuracy: 0.7828
# Epoch 4/30
# 3839/3839 [==============================] - 97s 25ms/step - loss: 0.4826 - accuracy: 0.8031 - val_loss: 0.5120 - val_accuracy: 0.7930
# Epoch 5/30
# 3839/3839 [==============================] - 101s 26ms/step - loss: 0.4486 - accuracy: 0.8177 - val_loss: 0.4987 - val_accuracy: 0.8000
# Epoch 6/30
# 3839/3839 [==============================] - 95s 25ms/step - loss: 0.4215 - accuracy: 0.8297 - val_loss: 0.4881 - val_accuracy: 0.8054
# Epoch 7/30
# 3839/3839 [==============================] - 98s 26ms/step - loss: 0.3996 - accuracy: 0.8391 - val_loss: 0.4753 - val_accuracy: 0.8133
# Epoch 8/30
# 3839/3839 [==============================] - 96s 25ms/step - loss: 0
# 3827/3827 [==============================] - 94s 25ms/step - loss: 0.2518 - accuracy: 0.9014 - val_loss: 0.4454 - val_accuracy: 0.8373
# Epoch 22/30
# 3827/3827 [==============================] - 108s 28ms/step - loss: 0.2484 - accuracy: 0.9025 - val_loss: 0.4539 - val_accuracy: 0.8376
# Epoch 23/30
# 3827/3827 [==============================] - 108s 28ms/step - loss: 0.2457 - accuracy: 0.9040 - val_loss: 0.4683 - val_accuracy: 0.8387
# Epoch 24/30
# 3827/3827 [==============================] - 100s 26ms/step - loss: 0.2407 - accuracy: 0.9058 - val_loss: 0.4603 - val_accuracy: 0.8373
# Epoch 25/30
# 3827/3827 [==============================] - 102s 27ms/step - loss: 0.2380 - accuracy: 0.9067 - val_loss: 0.4683 - val_accuracy: 0.8370
# Epoch 26/30
# 3827/3827 [==============================] - 100s 26ms/step - loss: 0.2356 - accuracy: 0.9079 - val_loss: 0.4627 - val_accuracy: 0.8383
# Epoch 27/30
# 3827/3827 [==============================] - 100s 26ms/step - loss: 0.2336 - accuracy: 0.9089 - val_loss: 0.4671 - val_accuracy: 0.8380
# Epoch 28/30
# 3827/3827 [==============================] - 106s 28ms/step - loss: 0.2303 - accuracy: 0.9104 - val_loss: 0.4779 - val_accuracy: 0.8371
# Epoch 29/30
# 3827/3827 [==============================] - 102s 27ms/step - loss: 0.2284 - accuracy: 0.9110 - val_loss: 0.4744 - val_accuracy: 0.8387
# Epoch 30/30
# 3827/3827 [==============================] - 105s 27ms/step - loss: 0.2264 - accuracy: 0.9123 - val_loss: 0.4771 - val_accuracy: 0.8375
# Evaluating performance for current model
# 6378/6378 [==============================] - 25s 4ms/step - loss: 0.4718 - accuracy: 0.8386

# %%
# Train on third batch
range_of_data = [3, 4]
train_model_on_minibatch(data_path, range_of_data, model)
# Out:
# Accessing /content/drive/My Drive/Colab Notebooks/Chess/data/scores3.npy
# Accessing /content/drive/My Drive/Colab Notebooks/Chess/data/scores4.npy
# Accessing /content/drive/My Drive/Colab Notebooks/Chess/data/positions3.npy
# Accessing /content/drive/My Drive/Colab Notebooks/Chess/data/positions4.npy
# Training model on minibatch
# Epoch 1/30
# 3839/3839 [==============================] - 97s 25ms/step - loss: 0.6097 - accuracy: 0.7570 - val_loss: 0.5213 - val_accuracy: 0.8003
# Epoch 2/30
# 3839/3839 [==============================] - 96s 25ms/step - loss: 0.5229 - accuracy: 0.7913 - val_loss: 0.4773 - val_accuracy: 0.8152
# Epoch 3/30
# 3839/3839 [==============================] - 96s 25ms/step - loss: 0.4686 - accuracy: 0.8140 - val_loss: 0.4571 - val_accuracy: 0.8212
# Epoch 4/30
# 3839/3839 [==============================] - 98s 25ms/step - loss: 0.4300 - accuracy: 0.8298 - val_loss: 0.4416 - val_accuracy: 0.8275
# Epoch 5/30
# 3839/3839 [==============================] - 98s 26ms/step - loss: 0.4025 - accuracy: 0.8405 - val_loss: 0.4394 - val_accuracy: 0.8290
# Epoch 6/30
# 3839/3839 [==============================] - 98s 26ms/step - loss: 0.3821 - accuracy: 0.8497 - val_loss: 0.4303 - val_accuracy: 0.8325
# Epoch 7/30
# 3839/3839 [==============================] - 97s 25ms/step - loss: 0.3629 - accuracy: 0.8571 - val_loss: 0.4293 - val_accuracy: 0.8334
# Epoch 8/30
# 3839/3839 [==============================] - 100s 26ms/step - loss: 0.3479 - accuracy: 0.8633 - val_loss: 0.4281 - val_accuracy: 0.8345
# Epoch 9/30
# 3839/3839 [==============================] - 98s 25ms/step - loss: 0.3370 - accuracy: 0.8674 - val_loss: 0.4276 - val_accuracy: 0.8340
# Epoch 10/30
# 3839/3839 [==============================] - 96s 25ms/step - loss: 0.3257 - accuracy: 0.8717 - val_loss: 0.4309 - val_accuracy: 0.8336
# Epoch 11/30
# 3839/3839 [==============================] - 96s 25ms/step - loss: 0.3154 - accuracy: 0.8760 - val_loss: 0.4302 - val_accuracy: 0.8345
# Epoch 12/30
# 3839/3839 [==============================] - 96s 25ms/step - loss: 0.3076 - accuracy: 0.8789 - val_loss: 0.4319 - val_accuracy: 0.8361
# Epoch 13/30
# 3839/3839 [==============================] - 97s 25ms/step - loss: 0.3002 - accuracy: 0.8823 - val_loss: 0.4348 - val_accuracy: 0.8349
# Epoch 14/30
# 3839/3839 [==============================] - 97s 25ms/step - loss: 0.2940 - accuracy: 0.8850 - val_loss: 0.4387 - val_accuracy: 0.8335
# Epoch 15/30
# 3839/3839 [==============================] - 96s 25ms/step - loss: 0.2886 - accuracy: 0.8866 - val_loss: 0.4435 - val_accuracy: 0.8364
# Epoch 16/30
# 3839/3839 [==============================] - 97s 25ms/step - loss: 0.2815 - accuracy: 0.8899 - val_loss: 0.4419 - val_accuracy: 0.8353
# Epoch 17/30
# 3839/3839 [==============================] - 97s 25ms/step - loss: 0.2753 - accuracy: 0.8924 - val_loss: 0.4438 - val_accuracy: 0.8365
# Epoch 18/30
# 3839/3839 [==============================] - 99s 26ms/step - loss: 0.2710 - accuracy: 0.8942 - val_loss: 0.4441 - val_accuracy: 0.8369
# Epoch 19/30
# 3839/3839 [==============================] - 97s 25ms/step - loss: 0.2669 - accuracy: 0.8955 - val_loss: 0.4462 - val_accuracy: 0.8369
# Epoch 20/30
# 3839/3839 [==============================] - 96s 25ms/step - loss: 0.2622 - accuracy: 0.8977 - val_loss: 0.4484 - val_accuracy: 0.8366
# Epoch 21/30
# 3839/3839 [==============================] - 96s 25ms/step - loss: 0.2590 - accuracy: 0.8987 - val_loss: 0.4480 - val_accuracy: 0.8344
# Epoch 22/30
# 3839/3839 [==============================] - 96s 25ms/step - loss: 0.2558 - accuracy: 0.9000 - val_loss: 0.4637 - val_accuracy: 0.8353
# Epoch 23/30
# 3839/3839 [==============================] - 97s 25ms/step - loss: 0.2529 - accuracy: 0.9017 - val_loss: 0.4509 - val_accuracy: 0.8374
# Epoch 24/30
# 3839/3839 [==============================] - 98s 25ms/step - loss: 0.2490 - accuracy: 0.9031 - val_loss: 0.4623 - val_accuracy: 0.8367
# Epoch 25/30
# 3839/3839 [==============================] - 96s 25ms/step - loss: 0.2460 - accuracy: 0.9042 - val_loss: 0.4541 - val_accuracy: 0.8359
# Epoch 26/30
# 3839/3839 [==============================] - 96s 25ms/step - loss: 0.2422 - accuracy: 0.9060 - val_loss: 0.4662 - val_accuracy: 0.8353
# Epoch 27/30
# 3839/3839 [==============================] - 97s 25ms/step - loss: 0.2392 - accuracy: 0.9072 - val_loss: 0.4622 - val_accuracy: 0.8364
# Epoch 28/30
# 3839/3839 [==============================] - 94s 25ms/step - loss: 0.2371 - accuracy: 0.9081 - val_loss: 0.4665 - val_accuracy: 0.8378
# Epoch 29/30
# 3839/3839 [==============================] - 95s 25ms/step - loss: 0.2333 - accuracy: 0.9097 - val_loss: 0.4663 - val_accuracy: 0.8377
# Epoch 30/30
# 3839/3839 [==============================] - 94s 25ms/step - loss: 0.2320 - accuracy: 0.9101 - val_loss: 0.4634 - val_accuracy: 0.8378
# Evaluating performance for current model
# 6398/6398 [==============================] - 24s 4ms/step - loss: 0.4607 - accuracy: 0.8389

# %%
# Save final model
save_model(model, '/content/drive/My Drive/Colab Notebooks/Chess/final')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Colab Notebooks/Chess/final/assets

# %%
# Train on fourth batch
range_of_data = [4, 5]
train_model_on_minibatch(data_path, range_of_data, model)
# Out:
# Accessing /content/drive/My Drive/Colab Notebooks/Chess/data/scores4.npy
# Accessing /content/drive/My Drive/Colab Notebooks/Chess/data/scores5.npy
# Accessing /content/drive/My Drive/Colab Notebooks/Chess/data/positions4.npy
# Accessing /content/drive/My Drive/Colab Notebooks/Chess/data/positions5.npy

# %%
# Train on fifth batch
range_of_data = [5, 6]
train_model_on_minibatch(data_path, range_of_data, model)

# %%
# Train on sixth batch
range_of_data = [6, 7]
train_model_on_minibatch(data_path, range_of_data, model)

# %%
# Train on sixth batch
range_of_data = [7, 8]
train_model_on_minibatch(data_path, range_of_data, model)

# %%
# Train on sixth batch
range_of_data = [8, 9]
train_model_on_minibatch(data_path, range_of_data, model)

# %%
# Train on sixth batch
range_of_data = [9, 10]
train_model_on_minibatch(data_path, range_of_data, model)

# %%
# Save final model
save_model(model, '/content/drive/My Drive/Colab Notebooks/Chess/final')
